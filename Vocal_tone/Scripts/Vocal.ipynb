# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    X, sample_rate = librosa.load(os.path.join(file_name),res_type='kaiser_fast')
    if chroma:
        stft = np.abs(librosa.stft(X))
    result = np.array([])
    if mfcc:
        mfcc = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result = np.hstack((result,mfcc))
    if chroma:
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
        result = np.hstack((result, chroma))
    if mel:
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
        result = np.hstack((result, mel))
    return result

# %%
emotions = {'01':'Happy', '02':'Sad', '03':'Angry', '04':'Neutral'}
observed_emotions = ['Happy', 'Sad', 'Angry', 'Neutral']

# %%
def load_data(test_size=0.2):
    x,y = [],[]
    for folder in observed_emotions:
        filepath = os.path.join("C:\Ruchira\Academic\.IMMEDIATE\FYP\FYP\Datasets\Common\Vocal",folder)
        for filename in os.listdir(filepath):
            feature = extract_feature(os.path.join(filepath,filename), mfcc=True, chroma=True, mel=True)
            x.append(feature)
            y.append(folder)
    return train_test_split(np.array(x),y,test_size=test_size, train_size=0.75, random_state=9)

# %%
x_train, x_test, y_train, y_test = load_data(test_size=0.25)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.0039201  -0.00412348 -0.00294496 ... -0.00021733 -0.00020347
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-1.1323843e-03 -1.9751154e-03 -1.7958895e-03 ... -7.0623793e-07
#   1.2919363e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[6.7492579e-03 8.1355209e-03 7.7656279e-03 ... 3.4802666e-05 2.7781638e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00079536 -0.00077136 -0.00015825 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.0012878  0.00183349 0.00156191 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00307034 -0.00356553 -0.00304929 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-7.3481980e-03 -8.6159240e-03 -6.9034086e-03 ... -1.0494488e-08
#  -6.0408070e-07  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-2.0460261e-03 -2.8284800e-03 -4.0468266e-03 ...  9.8627817e-05
#   2.5605859e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-1.0783259e-02 -1.2029369e-02 -1.0006960e-02 ... -5.0050232e-05
#  -4.8262416e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00157851 0.00216272 0.00166211 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[9.5357170e-04 2.1867603e-03 2.3903304e-03 ... 7.2110284e-05 4.9467231e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 8.7873694e-03  1.0753942e-02  9.7955074e-03 ...  4.3818606e-08
#  -4.1569894e-08  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00252806 0.00239639 0.00131595 ... 0.000222   0.00019256 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.         0.         0.         ... 0.00026348 0.00017941 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[5.9972750e-04 9.4564934e-04 1.8397634e-03 ... 1.4382034e-05 2.7204198e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00150898 -0.002079   -0.00179888 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00142556 0.00083274 0.00010787 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00163923 -0.00222723 -0.00236538 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-7.2433520e-03 -7.8279674e-03 -5.9202854e-03 ... -2.0005168e-04
#  -9.3602081e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00071862 -0.00106798 -0.0005725  ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 2.8937061e-03  3.1871211e-03  2.5348146e-03 ... -3.4499612e-05
#  -2.6564749e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 0.0030515   0.00395066  0.00425385 ... -0.00035153 -0.00027695
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00880028 0.01121705 0.0099797  ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.0020183 0.0027768 0.0026917 ... 0.        0.        0.       ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-7.0966355e-04 -3.8484836e-04  8.5327163e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00150505 -0.00215481 -0.00195439 ... -0.00034825 -0.00031547
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-4.4326903e-03 -5.6408150e-03 -5.4065529e-03 ...  1.5854113e-05
#   1.6954597e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00192623 -0.00253332 -0.00170267 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 1.1998761e-03  9.2328771e-04  1.1864557e-04 ...  1.6341426e-05
#  -1.2616572e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[
-08  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 7.2509283e-03  9.0074474e-03  8.2668383e-03 ... -6.6988927e-05
#  -5.8456462e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00074655 0.00073549 0.000815   ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 1.6895713e-03  1.8532188e-03  9.2823041e-04 ... -1.0826961e-06
#   4.6021100e-07  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 1.7378000e-03  1.7144819e-03  1.1193854e-03 ... -2.4547460e-04
#  -9.5665375e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 0.00130822  0.00132449  0.00088279 ... -0.00022302 -0.00025993
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 3.7938990e-03  4.8621688e-03  4.4885515e-03 ... -6.0807582e-05
#  -6.8666654e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-3.3889294e-03 -4.3024742e-03 -3.7106615e-03 ...  2.3340863e-08
#   2.2100512e-08  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00713537 -0.00830435 -0.00707022 ...  0.00025224  0.00021687
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00162126 -0.0011671  -0.00073603 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00162186 -0.00159331 -0.00100627 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00128371 0.00203008 0.00194855 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00632288 -0.00681064 -0.00506141 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[1.3304385e-04 2.6801389e-04 3.8510660e-04 ... 5.4386517e-05 2.8041555e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.0048209  -0.00602825 -0.00536159 ... -0.00047629 -0.00039451
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.0058359  0.00737201 0.00663604 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00283305 -0.00288334 -0.00196902 ... -0.00013068 -0.00013491
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00307185 0.00346202 0.00300981 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00291152 0.00356437 0.00312016 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.00230433 0.00264587 0.00223965 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00033279 -0.0003631  -0.00057181 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-2.5666114e-03 -3.1887817e-03 -2.6533445e-03 ...  3.5162164e-05
#   7.9961128e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-1.6538362e-03 -1.7551502e-03 -1.0461910e-03 ... -6.8905916e-05
#  -4.8923153e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 8.9392951e-04  1.0533509e-03  8.7392901e-04 ... -8.5385633e-05
#  -4.2116622e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00579891 -0.00683544 -0.00590343 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00656185 -0.00785953 -0.00651478 ...  0.0003975   0.00030346
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[ 3.3564602e-03  3.7969896e-03  2.7808270e-03 ... -5.0905986e-05
#  -2.2226668e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.2002508e-06 2.1327396e-06
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.00265852 -0.00339544 -0.00315625 ... -0.00033081 -0.00024936
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[-0.001502   -0.00143526 -0.00078998 ... -0.00038254 -0.00016622
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)

# %%
x_train.shape
# Out:
# (3675, 180)

# %%
model = MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08,hidden_layer_sizes=(300,), learning_rate='adaptive',max_iter=500)

# %%
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
y_pred = model.predict(x_test)

# %%
score = accuracy_score(y_true=y_test,y_pred=y_pred)
score
# Out:
# 0.6481632653061224

# %%
def predict_audio(file_path):
    feature = extract_feature(os.path.join(file_path), mfcc=True, chroma=True, mel=True)
    x = [feature]
    result = model.predict_proba(x)
    print(result)

# %%
predict_audio("C:\Ruchira\Academic\.IMMEDIATE\FYP\FYP\Datasets\Personalized\Vocal\Splitted\\Neutral\\Neutral_out_1.m4a")
# Out:
# c:\Python311\Lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16448\320538601.py:13: FutureWarning: Pass y=[0.         0.         0.         ... 0.00041837 0.00055974 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)
# [[4.85306017e-01 4.96907835e-01 2.12417875e-04 1.75737307e-02]]

# %%
import joblib

# Assuming 'model' is your trained scikit-learn model
model_path = "Vocal.pkl"
joblib.dump(model, model_path)
# Out:
# ['Vocal.pkl']

# %%
loaded_model = joblib.load(model_path)
